# %% [markdown]
# - `pip install autoviz`

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Class will start at 6:05 PM
#
# In the meantime... fun fact!

# %% [markdown]
# - AutoViz: Automatically Visualize any dataset, any size with a single line of code 🤯🤯🤯

# %%
! pip install autoviz
# Out:
# Collecting autoviz
#   Using cached autoviz-0.1.58-py3-none-any.whl (64 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from autoviz) (4.5.0)
# Collecting emoji
#   Using cached emoji-2.2.0.tar.gz (240 kB)
#   Preparing metadata (setup.py) ... done
# Collecting textblob
#   Using cached textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Requirement already satisfied: bokeh>=2.4.2 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from autoviz) (2.4.3)
# Requirement already satisfied: pandas in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from autoviz) (1.5.3)
# Requirement already satisfied: holoviews>=1.14.6 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from autoviz) (1.15.4)
# Requirement already satisfied: ipython in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from autoviz) (8.10.0)
# Collecting pyamg
#   Using cached pyamg-4.2.3-cp39-cp39-macosx_10_9_x86_64.whl (1.5 MB)
# Collecting fsspec>=0.8.3
#   Downloading fsspec-2023.3.0-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.4/145.4 kB 2.3 MB/s eta 0:00:00a 0:00:01
# Collecting panel~=0.12.6
#   Using cached panel-0.12.7-py2.py3-none-any.whl (12.9 MB)
# Requirement already satisfied: jupyter in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from autoviz) (1.0.0)
# Collecting xgboost>=0.82
#   Using cached xgboost-1.7.4-py3-none-macosx_10_15_x86_64.macosx_11_0_x86_64.macosx_12_0_x86_64.whl (1.8 MB)
# Collecting wordcloud
#   Using cached wordcloud-1.8.2.2-cp39-cp39-macosx_10_9_x86_64.whl (160 kB)
# Collecting statsmodels
#   Downloading statsmodels-0.13.5-cp39-cp39-macosx_10_9_x86_64.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 4.9 MB/s eta 0:00:0000:0100:01
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 4.6 MB/s eta 0:00:00
# Collecting seaborn>=0.11.1
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 5.8 MB/s eta 0:00:00a 0:00:01
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from autoviz) (1.24.2)
# Requirement already satisfied: hvplot>=0.7.3 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from autoviz) (0.8.2)
# Requirement already satisfied: scikit-learn in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from autoviz) (1.2.2)
# Requirement already satisfied: matplotlib>=3.3.3 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from autoviz) (3.7.0)
# Requirement already satisfied: PyYAML>=3.10 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from bokeh>=2.4.2->autoviz) (6.0)
# Requirement already satisfied: Jinja2>=2.9 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from bokeh>=2.4.2->autoviz) (3.1.2)
# Requirement already satisfied: packaging>=16.8 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from bokeh>=2.4.2->autoviz) (23.0)
# Requirement already satisfied: pillow>=7.1.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from bokeh>=2.4.2->autoviz) (9.4.0)
# Requirement already satisfied: tornado>=5.1 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from bokeh>=2.4.2->autoviz) (6.2)
# Collecting holoviews>=1.14.6
#   Using cached holoviews-1.15.3-py2.py3-none-any.whl (4.3 MB)
#   Using cached holoviews-1.15.2-py2.py3-none-any.whl (4.3 MB)
#   Using cached holoviews-1.15.1-py2.py3-none-any.whl (4.3 MB)
#   Downloading holoviews-1.15.0-py2.py3-none-any.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 3.5 MB/s eta 0:00:0000:0100:01
#   Using cached holoviews-1.14.9-py2.py3-none-any.whl (4.3 MB)
# Requirement already satisfied: colorcet in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from holoviews>=1.14.6->autoviz) (3.0.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from holoviews>=1.14.6->autoviz) (2.2.1)
# Requirement already satisfied: param<2.0,>=1.9.3 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from holoviews>=1.14.6->autoviz) (1.12.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from matplotlib>=3.3.3->autoviz) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from matplotlib>=3.3.3->autoviz) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from matplotlib>=3.3.3->autoviz) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from matplotlib>=3.3.3->autoviz) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from matplotlib>=3.3.3->autoviz) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from matplotlib>=3.3.3->autoviz) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from matplotlib>=3.3.3->autoviz) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from pandas->autoviz) (2022.7.1)
# Requirement already satisfied: pyct>=0.4.4 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from panel~=0.12.6->autoviz) (0.5.0)
# Requirement already satisfied: requests in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from panel~=0.12.6->autoviz) (2.28.2)
# Requirement already satisfied: markdown in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from panel~=0.12.6->autoviz) (3.4.1)
# Requirement already satisfied: tqdm>=4.48.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from panel~=0.12.6->autoviz) (4.65.0)
# Requirement already satisfied: bleach in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from panel~=0.12.6->autoviz) (6.0.0)
# Collecting setuptools<61,>=42
#   Using cached setuptools-60.10.0-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: scipy in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from xgboost>=0.82->autoviz) (1.10.1)
# Requirement already satisfied: stack-data in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from ipython->autoviz) (0.6.2)
# Requirement already satisfied: matplotlib-inline in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from ipython->autoviz) (0.1.6)
# Requirement already satisfied: traitlets>=5 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from ipython->autoviz) (5.9.0)
# Requirement already satisfied: pexpect>4.3 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from ipython->autoviz) (4.8.0)
# Requirement already satisfied: decorator in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from ipython->autoviz) (5.1.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from ipython->autoviz) (3.0.37)
# Requirement already satisfied: appnope in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from ipython->autoviz) (0.1.3)
# Requirement already satisfied: backcall in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from ipython->autoviz) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from ipython->autoviz) (0.18.2)
# Requirement already satisfied: pickleshare in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from ipython->autoviz) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from ipython->autoviz) (2.14.0)
# Requirement already satisfied: qtconsole in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jupyter->autoviz) (5.4.0)
# Requirement already satisfied: notebook in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jupyter->autoviz) (6.5.2)
# Requirement already satisfied: nbconvert in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jupyter->autoviz) (7.2.9)
# Requirement already satisfied: ipywidgets in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jupyter->autoviz) (8.0.4)
# Requirement already satisfied: ipykernel in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jupyter->autoviz) (6.21.2)
# Requirement already satisfied: jupyter-console in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jupyter->autoviz) (6.6.1)
# Collecting regex>=2021.8.3
#   Downloading regex-2023.3.23-cp39-cp39-macosx_10_9_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.4/294.4 kB 7.0 MB/s eta 0:00:0000:01
# Requirement already satisfied: joblib in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from nltk->autoviz) (1.2.0)
# Collecting click
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from scikit-learn->autoviz) (3.1.0)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=3.1.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.3->autoviz) (3.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jedi>=0.16->ipython->autoviz) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from Jinja2>=2.9->bokeh>=2.4.2->autoviz) (2.1.2)
# Requirement already satisfied: six in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels->autoviz) (1.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from pexpect>4.3->ipython->autoviz) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython->autoviz) (0.2.6)
# Requirement already satisfied: webencodings in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from bleach->panel~=0.12.6->autoviz) (0.5.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from ipykernel->jupyter->autoviz) (5.2.0)
# Requirement already satisfied: comm>=0.1.1 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from ipykernel->jupyter->autoviz) (0.1.2)
# Requirement already satisfied: nest-asyncio in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from ipykernel->jupyter->autoviz) (1.5.6)
# Requirement already satisfied: pyzmq>=20 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from ipykernel->jupyter->autoviz) (25.0.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from ipykernel->jupyter->autoviz) (8.0.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from ipykernel->jupyter->autoviz) (1.6.6)
# Requirement already satisfied: psutil in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from ipykernel->jupyter->autoviz) (5.9.4)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from ipywidgets->jupyter->autoviz) (3.0.5)
# Requirement already satisfied: widgetsnbextension~=4.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from ipywidgets->jupyter->autoviz) (4.0.5)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from markdown->panel~=0.12.6->autoviz) (6.0.0)
# Requirement already satisfied: tinycss2 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from nbconvert->jupyter->autoviz) (1.2.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from nbconvert->jupyter->autoviz) (0.2.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from nbconvert->jupyter->autoviz) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from nbconvert->jupyter->autoviz) (0.7.2)
# Requirement already satisfied: defusedxml in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from nbconvert->jupyter->autoviz) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from nbconvert->jupyter->autoviz) (4.11.2)
# Requirement already satisfied: nbformat>=5.1 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from nbconvert->jupyter->autoviz) (5.7.3)
# Requirement already satisfied: mistune<3,>=2.0.3 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from nbconvert->jupyter->autoviz) (2.0.5)
# Requirement already satisfied: nbclassic>=0.4.7 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from notebook->jupyter->autoviz) (0.5.2)
# Requirement already satisfied: argon2-cffi in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from notebook->jupyter->autoviz) (21.3.0)
# Requirement already satisfied: ipython-genutils in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from notebook->jupyter->autoviz) (0.2.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from notebook->jupyter->autoviz) (0.17.1)
# Requirement already satisfied: prometheus-client in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from notebook->jupyter->autoviz) (0.16.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from notebook->jupyter->autoviz) (1.8.0)
# Requirement already satisfied: qtpy>=2.0.1 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from qtconsole->jupyter->autoviz) (2.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from requests->panel~=0.12.6->autoviz) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from requests->panel~=0.12.6->autoviz) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from requests->panel~=0.12.6->autoviz) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from requests->panel~=0.12.6->autoviz) (3.4)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from stack-data->ipython->autoviz) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from stack-data->ipython->autoviz) (1.2.0)
# Requirement already satisfied: pure-eval in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from stack-data->ipython->autoviz) (0.2.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->autoviz) (3.0.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook->jupyter->autoviz) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook->jupyter->autoviz) (2.3.0)
# Requirement already satisfied: jsonschema>=2.6 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from nbformat>=5.1->nbconvert->jupyter->autoviz) (4.17.3)
# Requirement already satisfied: fastjsonschema in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from nbformat>=5.1->nbconvert->jupyter->autoviz) (2.16.2)
# Requirement already satisfied: argon2-cffi-bindings in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from argon2-cffi->notebook->jupyter->autoviz) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter->autoviz) (2.4)
# Requirement already satisfied: attrs>=17.4.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->autoviz) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->autoviz) (0.19.3)
# Requirement already satisfied: jupyter-events>=0.4.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->autoviz) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->autoviz) (0.4.4)
# Requirement already satisfied: websocket-client in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->autoviz) (1.5.1)
# Requirement already satisfied: anyio>=3.1.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->autoviz) (3.6.2)
# Requirement already satisfied: cffi>=1.0.1 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->autoviz) (1.15.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->autoviz) (1.3.0)
# Requirement already satisfied: pycparser in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->autoviz) (2.21)
# Requirement already satisfied: rfc3339-validator in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->autoviz) (0.1.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->autoviz) (2.0.7)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->autoviz) (0.1.1)
# Requirement already satisfied: isoduration in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->autoviz) (20.11.0)
# Requirement already satisfied: fqdn in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->autoviz) (1.5.1)
# Requirement already satisfied: uri-template in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->autoviz) (1.2.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->autoviz) (2.3)
# Requirement already satisfied: webcolors>=1.11 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->autoviz) (1.12)
# Requirement already satisfied: arrow>=0.15.0 in /Users/vivianamarquez/opt/anaconda3/envs/IntroML/lib/python3.9/site-packages (from isoduration->jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->autoviz) (1.2.3)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234912 sha256=7c65a50b98efa434c48e6b0b4f04253e42d4ec7b07272f0e938c160b3fce5e99
#   Stored in directory: /Users/vivianamarquez/Library/Caches/pip/wheels/34/1c/15/553c4ad364178bab0c80f1fec134dec07ad6f1afbf15e360c1
# Successfully built emoji
# Installing collected packages: xlrd, setuptools, regex, patsy, fsspec, emoji, click, xgboost, pyamg, nltk, wordcloud, textblob, statsmodels, seaborn, panel, holoviews, autoviz
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.6.3
#     Uninstalling setuptools-65.6.3:
#       Successfully uninstalled setuptools-65.6.3
#   Attempting uninstall: panel
#     Found existing installation: panel 0.14.4
#     Uninstalling panel-0.14.4:
#       Successfully uninstalled panel-0.14.4
#   Attempting uninstall: holoviews
#     Found existing installation: holoviews 1.15.4
#     Uninstalling holoviews-1.15.4:
#       Successfully uninstalled holoviews-1.15.4
# Successfully installed autoviz-0.1.58 click-8.1.3 emoji-2.2.0 fsspec-2023.3.0 holoviews-1.14.9 nltk-3.8.1 panel-0.12.7 patsy-0.5.3 pyamg-4.2.3 regex-2023.3.23 seaborn-0.12.2 setuptools-60.10.0 statsmodels-0.13.5 textblob-0.17.1 wordcloud-1.8.2.2 xgboost-1.7.4 xlrd-2.0.1

# %%
from autoviz.AutoViz_Class import AutoViz_Class
import matplotlib.pyplot as plt

AV = AutoViz_Class()

filename = "../data/insurance.csv"

# %matplotlib inline
dft = AV.AutoViz(filename) # chart_format='html'
# Out:
# Shape of your Data Set loaded: (1338, 7)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# Data cleaning improvement suggestions. Complete them before proceeding to ML modeling.
# <style type="text/css">
# #T_28c3f_row0_col0, #T_28c3f_row0_col4, #T_28c3f_row5_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_28c3f_row0_col1, #T_28c3f_row0_col6, #T_28c3f_row1_col1, #T_28c3f_row1_col6, #T_28c3f_row2_col1, #T_28c3f_row2_col6, #T_28c3f_row3_col1, #T_28c3f_row3_col6, #T_28c3f_row4_col1, #T_28c3f_row4_col6, #T_28c3f_row5_col1, #T_28c3f_row5_col6, #T_28c3f_row6_col1, #T_28c3f_row6_col6 {
#   font-family: Segoe UI;
# }
# #T_28c3f_row0_col2, #T_28c3f_row0_col3, #T_28c3f_row0_col5, #T_28c3f_row1_col2, #T_28c3f_row1_col3, #T_28c3f_row1_col5, #T_28c3f_row2_col2, #T_28c3f_row2_col3, #T_28c3f_row2_col5, #T_28c3f_row3_col0, #T_28c3f_row3_col2, #T_28c3f_row3_col3, #T_28c3f_row3_col4, #T_28c3f_row3_col5, #T_28c3f_row4_col0, #T_28c3f_row4_col2, #T_28c3f_row4_col3, #T_28c3f_row4_col4, #T_28c3f_row5_col0, #T_28c3f_row5_col2, #T_28c3f_row5_col3, #T_28c3f_row5_col4, #T_28c3f_row6_col0, #T_28c3f_row6_col2, #T_28c3f_row6_col3, #T_28c3f_row6_col4 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_28c3f_row1_col0, #T_28c3f_row1_col4 {
#   background-color: #fc8767;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_28c3f_row2_col0, #T_28c3f_row2_col4 {
#   background-color: #fff0e8;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_28c3f_row4_col5 {
#   background-color: #fb6d4d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_28c3f_row6_col5 {
#   background-color: #fc8666;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_28c3f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28c3f_level0_col0" class="col_heading level0 col0" >Nuniques</th>
#       <th id="T_28c3f_level0_col1" class="col_heading level0 col1" >dtype</th>
#       <th id="T_28c3f_level0_col2" class="col_heading level0 col2" >Nulls</th>
#       <th id="T_28c3f_level0_col3" class="col_heading level0 col3" >Nullpercent</th>
#       <th id="T_28c3f_level0_col4" class="col_heading level0 col4" >NuniquePercent</th>
#       <th id="T_28c3f_level0_col5" class="col_heading level0 col5" >Value counts Min</th>
#       <th id="T_28c3f_level0_col6" class="col_heading level0 col6" >Data cleaning improvement suggestions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28c3f_level0_row0" class="row_heading level0 row0" >charges</th>
#       <td id="T_28c3f_row0_col0" class="data row0 col0" >1337</td>
#       <td id="T_28c3f_row0_col1" class="data row0 col1" >float64</td>
#       <td id="T_28c3f_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_28c3f_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_28c3f_row0_col4" class="data row0 col4" >99.925262</td>
#       <td id="T_28c3f_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_28c3f_row0_col6" class="data row0 col6" >skewed: cap or drop outliers</td>
#     </tr>
#     <tr>
#       <th id="T_28c3f_level0_row1" class="row_heading level0 row1" >bmi</th>
#       <td id="T_28c3f_row1_col0" class="data row1 col0" >548</td>
#       <td id="T_28c3f_row1_col1" class="data row1 col1" >float64</td>
#       <td id="T_28c3f_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_28c3f_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_28c3f_row1_col4" class="data row1 col4" >40.956652</td>
#       <td id="T_28c3f_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_28c3f_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_28c3f_level0_row2" class="row_heading level0 row2" >age</th>
#       <td id="T_28c3f_row2_col0" class="data row2 col0" >47</td>
#       <td id="T_28c3f_row2_col1" class="data row2 col1" >int64</td>
#       <td id="T_28c3f_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_28c3f_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_28c3f_row2_col4" class="data row2 col4" >3.512706</td>
#       <td id="T_28c3f_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_28c3f_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_28c3f_level0_row3" class="row_heading level0 row3" >children</th>
#       <td id="T_28c3f_row3_col0" class="data row3 col0" >6</td>
#       <td id="T_28c3f_row3_col1" class="data row3 col1" >int64</td>
#       <td id="T_28c3f_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_28c3f_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_28c3f_row3_col4" class="data row3 col4" >0.448430</td>
#       <td id="T_28c3f_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_28c3f_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_28c3f_level0_row4" class="row_heading level0 row4" >region</th>
#       <td id="T_28c3f_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_28c3f_row4_col1" class="data row4 col1" >object</td>
#       <td id="T_28c3f_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_28c3f_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_28c3f_row4_col4" class="data row4 col4" >0.298954</td>
#       <td id="T_28c3f_row4_col5" class="data row4 col5" >324</td>
#       <td id="T_28c3f_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_28c3f_level0_row5" class="row_heading level0 row5" >sex</th>
#       <td id="T_28c3f_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_28c3f_row5_col1" class="data row5 col1" >object</td>
#       <td id="T_28c3f_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_28c3f_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_28c3f_row5_col4" class="data row5 col4" >0.149477</td>
#       <td id="T_28c3f_row5_col5" class="data row5 col5" >662</td>
#       <td id="T_28c3f_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_28c3f_level0_row6" class="row_heading level0 row6" >smoker</th>
#       <td id="T_28c3f_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_28c3f_row6_col1" class="data row6 col1" >object</td>
#       <td id="T_28c3f_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_28c3f_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_28c3f_row6_col4" class="data row6 col4" >0.149477</td>
#       <td id="T_28c3f_row6_col5" class="data row6 col5" >274</td>
#       <td id="T_28c3f_row6_col6" class="data row6 col6" ></td>
#     </tr>
#   </tbody>
# </table>
#     7 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# Number of All Scatter Plots = 3
# All Plots done
# Time to run AutoViz = 89 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################

# %% [markdown]
# # Week 6: Ensemble models and model optimization/interpretation
# ### Intro to Machine Learning | Professional Certificate course
#
# Viviana Marquez,  M.Sc.<br>
# March 29, 2023
#
# <br>
#
# <img src='../img/all/di.jpeg' style='width:500px; float: left; margin: 0px 30px 15px 0px'>

# %% [markdown]
# # 🚀 Today's agenda
#
# **Part 1:**
#
# - Ensemble Learning
#     - Bagging
#     - Boosting
#     - Stacking

# %% [markdown]
# # 🚀 Today's agenda
#
# **Part 2:**
#
# - Model optimization
#     - Cross-validation
#     - Hyperparameter tuning
#     - Grid search
# - Model interpretation
#     - Feature importance
#     - Feature selection

# %% [markdown]
# # ⏪ Last class recap
#
# - Classification models continuation
#     - Logistic regression
#     - Support Vector Machines (SVM)
#     - Naive-Bayes
#
# - Non-parametric models
#     - KNN
#     - Decision trees

# %% [markdown]
# ### Conda environment commands
#
# - `conda activate IntroML`
#     - Launch `jupyter notebook`
#
#
# ### Alternative
#
# Google Colab: https://colab.research.google.com/

# %% [markdown]
# # 🚀 Part 1

# %% [markdown]
# # ❇️ Classification models

# %% [markdown]
# # Decision trees
#
# <br>
# <center>
#     <img src='../img/class_5/dt.gif' style='height:350px; float: center; margin: 0px 0px 0px 0px'>
# </center>

# %% [markdown]
# - It is an algorithm that can be used for both classification and regression
# - The goal is to create a model that predicts the value of the target variable by learning simple decision rules

# %% [markdown]
# # Decision trees

# %% [markdown]
# ### 👍 Pros
#
# - The predictions have an elegant probabilistic representation
# - The model can be regularized to avoid overfitting

# %% [markdown]
# ### 👎 Cons
#
# - Prone to overfitting
# - Unstable, but that can be solved with an ensemble model

# %% [markdown]
# # ❇️ Random forests

# %% [markdown]
# <center>
#     <img src='../img/class_5/spoiler.jpg' style='height:350px; float: center; margin: 0px 0px 0px 0px'>
# </center>

# %% [markdown]
# <center>
#     <img src='../img/class_5/rf.png' style='height:350px; float: center; margin: 0px 0px 0px 0px'>
# </center>

# %% [markdown]
# # ⏪ Today's recap
#
# - Ensemble Learning
#     - Bagging
#     - Boosting
#     - Stacking
#
# - Model optimization
#     - Cross-validation
#     - Hyperparameter tuning
#     - Grid search
#
# - Model interpretation
#     - Feature importance
#     - Feature selection

# %% [markdown]
# # 👮‍♀️ Misc:
#
# - Self-graded quiz will be posted in the next hour
# - 💪 Ungraded homework will be posted tonight or tomorrow morning
# - Office hours on Friday at 12 PM PST and Monday 6 PM PST (Zoom link is posted in Canvas)

# %% [markdown]
# <center>
# <img src='../img/all/bye.gif' style='height:400px;'>
# </center>
#
# # Next class:
# - Unsupervised learning
#     - K-means and distance metrics
#     - Hierarchical clustering
#     - PCA
# - Farewell
#     - Brief note on data literacy/data ethics
#     - Student requests
